# %% [markdown]
# <a href="https://colab.research.google.com/github/JimmyMcKegger/colabs/blob/main/Copy_of_label_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

# %%
classifier = pipeline("zero-shot-classification",model="sileod/deberta-v3-base-tasksource-nli")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/18.5k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/738M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]

# %% [markdown]
# )

# %%
candidate_labels = ['Admin API',
                    'Storefront API',
                    'Partners API',
                    'Payments API',
                    'Orders',
                    'Fulfillments',
                    'Subscriptions',
                    'Bundles',
                    'Liquid',
                    'AJAX',
                    'Themes',
                    'HTML',
                    'CSS',
                    'JavaScript',
                    'GraphQL',
                    'REST',
                    'OAuth',
                    'HTTP',
                    'JWT',
                    'access scopes',
                    'webhooks',
                    'checkout extensibility',
                    'cart management',
                    'functions',
                    'discounts',
                    'Hydrogen',
                    'Oxygen',
                    'React',
                    'Headless',
                    'metafields',
                    'metaobjects',
                    'products',
                    'variants',
                    'bulk operations',
                    'Online Store Themes',
                    'Shopify Checkout Classic',
                    'Storefront API',
                    'Hydrogen & Remix',
                    'Oxygen',
                    'Payments Apps Platform',
                    'REST & GraphQL API Patterns & Operations (Anything related to API Patterns and Operations including API Versioning/Deprecation, Auth, Timeout, Scopes and Rate Limits/Throttling.)',
                    'Webhook Management',
                    'Pixels',
                    'Shopify Scripts',
                    'ShopifyQL',
                    'Notification Templates & Shopify Email',
                    'Fully understanding how a 3rd party developed Script is configured, developed, or meant to function',
                    'Partner API & Partner Platform',
                    'Admin UI Extensions',
                    'Shop App',
                    'Metaobjects and Metafields',
                    'Customer Account API',
                    'Carrier Services API',
                    'Shopify CLI',
                    'Multipass/SSO',
                    'App Bridge',
                    'Sales Channels/Marketplace Kit',
                    'Shopify POS',
                    'App Extensions',
                    'Shopify Forms',
                    'Shopify Bundles',
                    'Shopify Search and Discovery',
                    'Shopify Geolocations',
                    'Other Shopify Apps',
                    'Checkout Extensibility (Work in Progress)',
                    'Shopify Functions (Work in Progress)']

# %%
text = """

"""

# %%
result = classifier(text, candidate_labels)

# %%
result.__class__
result.keys()
# Out:
# dict_keys(['sequence', 'labels', 'scores'])

# %%
for i, l in enumerate(result['labels']):
  if result['scores'][i] < 0.05:
    break
  print(f"{l}: {result['scores'][i]}")
# Out:
# orders: 0.22920876741409302
# Orders: 0.2054872214794159
